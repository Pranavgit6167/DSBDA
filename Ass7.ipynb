# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("HousingData.csv")

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df1=pd.read_csv('Singlevar.csv')

# %%
df1
# Out:
#     Area   Price
# 0    500  100000
# 1    700  150000
# 2    900  200000
# 3   1100  250000
# 4   1300  300000
# 5   1000  150000
# 6   1200  170000
# 7   1300  180000
# 8   1500  200000
# 9   1600  210000
# 10  1800  230000
# 11  2000  250000
# 12  2200  270000
# 13  2400  290000
# 14  2500  300000
# 15  2700  320000
# 16  2800  330000
# 17  3000  350000
# 18  3200  370000
# 19  3400  390000
# 20  3500  400000
# 21  3700  420000
# 22  3800  430000
# 23  4000  450000
# 24  4200  470000
# 25  4400  490000
# 26  4500  500000
# 27  4700  520000
# 28  4800  530000
# 29  5000  550000
# 30  5200  570000
# 31  5400  590000
# 32  5500  600000
# 33  5700  620000
# 34  5800  630000
# 35  6000  650000
# 36  6200  670000
# 37  6400  690000
# 38  6500  700000
# 39  6700  720000
# 40  6800  730000
# 41  7000  750000
# 42  7200  770000
# 43  7400  790000
# 44  7500  800000
# 45  7700  820000
# 46  7800  830000
# 47  8000  850000
# 48  8200  870000
# 49  8400  890000
# 50  8500  900000
# ...

# %%
from sklearn import linear_model

# %%
reg=linear_model.LinearRegression()

# %%
x1=np.array(df1.Area).reshape(-1,1)
y1=np.array(df1.Price).reshape(-1,1)

# %%
reg.fit(x1,y1)
# Out:
# LinearRegression()

# %%
reg.predict([[8000]])
# Out:
# array([[845369.47817699]])

# %% [markdown]
# # Multiple regression

# %%
df.dropna()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
x=df.drop(['MEDV'],axis=1)
y=df.MEDV

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,ytrain,xtest,ytest=train_test_split(x,y ,test_size=0.2,random_state=0)

# %%
import sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
model=lm.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-c5021abad1c5> in <module>
# ----> 1 model=lm.fit(xtrain,ytrain)
#
# ~/.local/lib/python3.6/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     517
#     518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
# --> 519                                    y_numeric=True, multi_output=True)
#     520
#     521         if sample_weight is not None:
#
# ~/.local/lib/python3.6/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
# ...

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
Q1 = np.percentile(df, 25,
                interpolation = 'midpoint')
 
Q3 = np.percentile(df, 75,
                interpolation = 'midpoint')
IQR = Q3 - Q1

# %%
# Out:
# nan

# %%
upper=np.where(df>=(Q3+1.5*IQR))
lower=np.where(df<=(Q1-1.5*IQR))

# %%
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
df.drop(upper[0], inplace=True)
df.drop(lower[0],inplace=True)

# %%
df.boxplot()
# Out:
# <AxesSubplot:>
