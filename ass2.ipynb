# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('Stud_Performance.csv')

# %%
df
# Out:
#     Roll No.     Name  FE Percentage  SE Percentage  TE Percentage  \
# 0          1   Pranav            NaN           80.0             87
# 1          2  Janhavi           70.0           80.0             90
# 2          3  Krishna           78.0           76.0             74
# 3          4   Prachi           56.0           60.0             67
# 4          5  Srushti           67.0            NaN             56
# 5          6    Priya           54.0           78.0            400
# 6          7   Sakshi           54.0           54.0             89
# 7          8   Prachi           37.0           78.0             75
# 8          9   Nikhil           58.0          500.0             65
# 9         10   Rajesh           43.0         1000.0             88
# 10        11    Lalit           55.0           67.0             45
# 11        12   Siddhi           60.0           78.0             87
# 12        13    ishan            NaN           37.0             56
# ...

# %%
df.dropna(inplace=True)

# %%
df_mean = df[['FE Percentage','SE Percentage','TE Percentage','BE Percentage']]  
for i in df_mean.columns:
    df_mean[i].fillna(df_mean[i].mean(), inplace=True)  # Fill missing values with mean of each column

# Now df_mean contains the DataFrame with missing values filled with the mean of each column
# Out:
# C:\Users\Pranav\AppData\Local\Temp\ipykernel_5352\4045860845.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mean[i].fillna(df_mean[i].mean(), inplace=True)  # Fill missing values with mean of each column

# %%
 
for i in df[['FE Percentage','SE Percentage','TE Percentage','BE Percentage']].columns:
    df[i].fillna(df[i].mean(), inplace=True)

# %%
df
# Out:
#     Roll No.     Name  FE Percentage  SE Percentage  TE Percentage  \
# 0          1   Pranav      54.692308      80.000000             87
# 1          2  Janhavi      70.000000      80.000000             90
# 2          3  Krishna      78.000000      76.000000             74
# 3          4   Prachi      56.000000      60.000000             67
# 4          5  Srushti      67.000000     164.857143             56
# 5          6    Priya      54.000000      78.000000            400
# 6          7   Sakshi      54.000000      54.000000             89
# 7          8   Prachi      37.000000      78.000000             75
# 8          9   Nikhil      58.000000     500.000000             65
# 9         10   Rajesh      43.000000    1000.000000             88
# 10        11    Lalit      55.000000      67.000000             45
# 11        12   Siddhi      60.000000      78.000000             87
# 12        13    ishan      54.692308      37.000000             56
# ...

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Roll No.         0
# Name             0
# FE Percentage    0
# SE Percentage    0
# TE Percentage    0
# BE Percentage    0
# dtype: int64

# %%
df_mode=df
for i in df_mode.columns:
 df_mode[i].fillna(df_mode[i].mode()[0],inplace=True)

df_mode
# Out:
#     Roll No.     Name  FE Percentage  SE Percentage  TE Percentage  \
# 0          1   Pranav           54.0           80.0             87
# 1          2  Janhavi           70.0           80.0             90
# 2          3  Krishna           78.0           76.0             74
# 3          4   Prachi           56.0           60.0             67
# 4          5  Srushti           67.0           78.0             56
# 5          6    Priya           54.0           78.0            400
# 6          7   Sakshi           54.0           54.0             89
# 7          8   Prachi           37.0           78.0             75
# 8          9   Nikhil           58.0          500.0             65
# 9         10   Rajesh           43.0         1000.0             88
# 10        11    Lalit           55.0           67.0             45
# 11        12   Siddhi           60.0           78.0             87
# 12        13    ishan           54.0           37.0             56
# ...

# %%
df_median=df
for i in df_median[['FE Percentage','SE Percentage','TE Percentage','BE Percentage']].columns:
    df_median.fillna(df_median[i].median(),inplace = True)
df_median
# Out:
#     Roll No.     Name  FE Percentage  SE Percentage  TE Percentage  \
# 0          1   Pranav           54.0           80.0             87
# 1          2  Janhavi           70.0           80.0             90
# 2          3  Krishna           78.0           76.0             74
# 3          4   Prachi           56.0           60.0             67
# 4          5  Srushti           67.0           78.0             56
# 5          6    Priya           54.0           78.0            400
# 6          7   Sakshi           54.0           54.0             89
# 7          8   Prachi           37.0           78.0             75
# 8          9   Nikhil           58.0          500.0             65
# 9         10   Rajesh           43.0         1000.0             88
# 10        11    Lalit           55.0           67.0             45
# 11        12   Siddhi           60.0           78.0             87
# 12        13    ishan           54.0           37.0             56
# ...

# %%
import seaborn as sns
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
df
# Out:
#     Roll No.     Name  FE Percentage  SE Percentage  TE Percentage  \
# 0          1   Pranav            NaN           80.0             87
# 1          2  Janhavi           70.0           80.0             90
# 2          3  Krishna           78.0           76.0             74
# 3          4   Prachi           56.0           60.0             67
# 4          5  Srushti           67.0            NaN             56
# 5          6    Priya           54.0           78.0            400
# 6          7   Sakshi           54.0           54.0             89
# 7          8   Prachi           37.0           78.0             75
# 8          9   Nikhil           58.0          500.0             65
# 9         10   Rajesh           43.0         1000.0             88
# 10        11    Lalit           55.0           67.0             45
# 11        12   Siddhi           60.0           78.0             87
# 12        13    ishan            NaN           37.0             56
# ...

# %%
df1=pd.read_csv('Stud_Performance.csv')

# %%
df1
# Out:
#     Roll No.     Name  FE Percentage  SE Percentage  TE Percentage  \
# 0          1   Pranav            NaN           80.0             87
# 1          2  Janhavi           70.0           80.0             90
# 2          3  Krishna           78.0           76.0             74
# 3          4   Prachi           56.0           60.0             67
# 4          5  Srushti           67.0            NaN             56
# 5          6    Priya           54.0           78.0            400
# 6          7   Sakshi           54.0           54.0             89
# 7          8   Prachi           37.0           78.0             75
# 8          9   Nikhil           58.0          500.0             65
# 9         10   Rajesh           43.0         1000.0             88
# 10        11    Lalit           55.0           67.0             45
# 11        12   Siddhi           60.0           78.0             87
# 12        13    ishan            NaN           37.0             56
# ...

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df1.fillna(df.mean(numeric_only=True).round(1),inplace=True)

# %%
df1
# Out:
#     Roll No.     Name  FE Percentage  SE Percentage  TE Percentage  \
# 0          1   Pranav           54.6           80.0             87
# 1          2  Janhavi           70.0           80.0             90
# 2          3  Krishna           78.0           76.0             74
# 3          4   Prachi           56.0           60.0             67
# 4          5  Srushti           67.0          159.1             56
# 5          6    Priya           54.0           78.0            400
# 6          7   Sakshi           54.0           54.0             89
# 7          8   Prachi           37.0           78.0             75
# 8          9   Nikhil           58.0          500.0             65
# 9         10   Rajesh           43.0         1000.0             88
# 10        11    Lalit           55.0           67.0             45
# 11        12   Siddhi           60.0           78.0             87
# 12        13    ishan           54.6           37.0             56
# ...

# %%
df1.boxplot()
# Out:
# <Axes: >

# %%
q1=df['SE Percentage'].quantile(0.25)
q3=df['SE Percentage'].quantile(0.75)
iqr=q3-q1

higher=q3+1.5*iqr
lower=q1-1.5*iqr

upper=np.where(df['SE Percentage']>=higher)[0]
lower=np.where(df['SE Percentage']<=lower)[0]

# %%
upper
# Out:
# array([8, 9], dtype=int64)

# %%
lower
# Out:
# array([12], dtype=int64)

# %%
df_removed=df
df_removed.drop(index=upper,inplace=True)
df_removed.drop(index=lower,inplace=True)

# %%
df_removed
# Out:
#     Roll No.     Name  FE Percentage  SE Percentage  TE Percentage  \
# 0          1   Pranav           54.0           80.0             87
# 1          2  Janhavi           70.0           80.0             90
# 2          3  Krishna           78.0           76.0             74
# 3          4   Prachi           56.0           60.0             67
# 4          5  Srushti           67.0           78.0             56
# 5          6    Priya           54.0           78.0            400
# 6          7   Sakshi           54.0           54.0             89
# 7          8   Prachi           37.0           78.0             75
# 10        11    Lalit           55.0           67.0             45
# 11        12   Siddhi           60.0           78.0             87
# 13        14  Bhushan           39.0           54.0             67
# 14        15    rohan           40.0           66.0             45
#
#     BE Percentage
# 0            86.0
# 1           200.0
# 2            91.0
# ...

# %% [raw]
# df_removed.boxplot()

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(x=df[['FE Percentage','SE Percentage','TE Percentage','BE Percentage']])
plt.show()

# %%
plt.boxplot(df[['FE Percentage','SE Percentage','TE Percentage','BE Percentage']])
plt.show()

# %%
q1=df["TE Percentage"].quantile(0.25)
q3=df["TE Percentage"].quantile(0.75)
IQR=q3-q1

highter=q3+1.5*IQR
lower=q1-1.5*IQR

# %%
upper1=np.where(df["TE Percentage"]>=higher)
lower1=np.where(df["TE Percentage"]<=lower)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 upper1=np.where(df["TE Percentage"]>=higher).shape(1)
#       2 lower1=np.where(df["TE Percentage"]<=lower).shape(1)
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
upper1
# Out:
# (array([5], dtype=int64),)

# %%
lower
# Out:
# (array([], dtype=int64),)

# %%
 df_re=df
df_re.drop(index=upper[0],inplace=True)
df_re.drop(index=lower[0],inplace=True)

# %%
plt.boxplot(df[['FE Percentage','SE Percentage','TE Percentage','BE Percentage']])
plt.show()

# %%
df_re=df
q1=df["BE Percentage"].quantile(0.25)
q3=df["BE Percentage"].quantile(0.75)

iqr=q3-q1

higher=q3+1.5*iqr
lower=q1-1.5*iqr

# %%
upper=np.where(df["BE Percentage"]>=higher)[0]
lower=np.where(df["BE Percentage"]<=lower)[0]

# %%
upper
# Out:
# array([1], dtype=int64)

# %%
lower
# Out:
# array([], dtype=int64)

# %%
df_re.drop(index=upper,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df_re.drop(index=upper,inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
# ...

# %%
df_re
# Out:
#     Roll No.     Name  FE Percentage  SE Percentage  TE Percentage  \
# 0          1   Pranav           54.0           80.0             87
# 2          3  Krishna           78.0           76.0             74
# 3          4   Prachi           56.0           60.0             67
# 4          5  Srushti           67.0           78.0             56
# 6          7   Sakshi           54.0           54.0             89
# 7          8   Prachi           37.0           78.0             75
# 10        11    Lalit           55.0           67.0             45
# 11        12   Siddhi           60.0           78.0             87
# 13        14  Bhushan           39.0           54.0             67
# 14        15    rohan           40.0           66.0             45
#
#     BE Percentage
# 0            86.0
# 2            91.0
# 3            67.0
# 4            78.0
# 6            65.0
# 7            48.0
# 10           45.0
# 11           55.0
# 13           77.0
# 14           70.0

# %%
df
# Out:
#     Roll No.     Name  FE Percentage  SE Percentage  TE Percentage  \
# 0          1   Pranav           54.0           80.0             87
# 2          3  Krishna           78.0           76.0             74
# 3          4   Prachi           56.0           60.0             67
# 4          5  Srushti           67.0           78.0             56
# 6          7   Sakshi           54.0           54.0             89
# 7          8   Prachi           37.0           78.0             75
# 10        11    Lalit           55.0           67.0             45
# 11        12   Siddhi           60.0           78.0             87
# 13        14  Bhushan           39.0           54.0             67
# 14        15    rohan           40.0           66.0             45
#
#     BE Percentage
# 0            86.0
# 2            91.0
# 3            67.0
# 4            78.0
# 6            65.0
# 7            48.0
# 10           45.0
# 11           55.0
# 13           77.0
# 14           70.0

# %%
plt.boxplot(df[['FE Percentage','SE Percentage','TE Percentage','BE Percentage']])
plt.show()
